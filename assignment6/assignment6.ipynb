# %% [markdown]
# # Assignment 6

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your Emory code below

# %%
# Write your answer here:

print("2630972")
# Out:
# 2630972

# %% [markdown]
# <font size = "5">
#
# Import the "pandas", "matplotlib.pyplot", "numPy" and "statsmodels.formula.api" libraries

# %%
# Write your answer here:

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read the dataset labelled features.csv.
# - Create a ``` lambda ``` function that checks if horsepower $>$ 100
# - Create a new list that shows true if horsepower $>$ 100 and false <br>
# if horsepower $\leq$ 100.
# - Count how many cars have horsewpower $> 100$.
#
# To get full credit use either the apply or the map function <br>
# (see Lectures 7 and 8)

# %%
# Write your answer here

carfeatures = pd.read_csv("Data/features.csv")

carfeatures["horsepower"] = pd.to_numeric(carfeatures["horsepower"], errors = "coerce")

hp_greater100 = lambda horsepower: horsepower > 100

list_horsepower = list(map(hp_greater100, carfeatures["horsepower"]))

len(list_horsepower)
# Out:
# 398

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read the dataset labelled features.csv.
# - Define a global variable called ```threshold``` that takes the <br>
# value 3000
# - Subset the data to get one dataset with weight $>$ threshold and <br>
# another with weight $\le$ 3000. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets.<br>
#
# Note: Review how to define a global variable inside ```.query()```

# %%
# Write your answer here:

carfeatures = pd.read_csv("Data/features.csv")

threshold = 3000

weight_gt3000 = carfeatures.query("`weight` > @threshold")
weight_lt3000 = carfeatures.query("`weight` <= @threshold")

print(np.mean(weight_gt3000["acceleration"]))
print(np.mean(weight_lt3000["acceleration"]))
# Out:
# 14.7
# 16.202173913043477

# %% [markdown]
# <font size = "5">
#
# (c) Regression
#
# <font size = "3">
#
# In this exercise you are asked to plot acceleration vs. weight and to plot <br>
#  the best fit line.
#
# - Run a linear regression between acceleration and weight.
# - Extract the intercept and coefficient.
# - Using your predicted coefficients, compute the predicted value of acceleration
# - Plot a scatter plot with acceleration on the y axis and weight on the x axis.
# - On that same figure, plot a line with the predicted values of acceleration
#
# Do not forget to label your axes and title.

# %%
# Write your answer here:

acceleration = carfeatures["acceleration"]
weight = carfeatures["weight"]

model = smf.ols(formula = 'acceleration ~ weight', data = carfeatures)
results = model.fit()

predicted = results.params
print(predicted)

predicted_acceleration = predicted[0] + predicted[1] * weight

plt.scatter(x = weight, y = acceleration)
plt.plot(weight, predicted_acceleration, color = 'orange')

plt.legend(labels = ["Weight", "Predicted Acceleration Model"])
plt.show()
# Out:
# Intercept    19.606158
# weight       -0.001359
# dtype: float64

# %% [markdown]
# <font size = "5">
#
# (d) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your own code

fifa23 = pd.read_csv("Data/fifa23_players_basic.csv")

fifasorted = fifa23.sort_values(by = "Age", ascending = True)

fifasorted.iloc[0:5,]
# Out:
#             Known As        Full Name  ...  Attacking Work Rate  Defensive Work Rate
# 17956     A. Dithmer  Andreas Dithmer  ...               Medium               Medium
# 18014      J. Ardila      José Ardila  ...               Medium               Medium
# 16084       S. Ngoma      Serge Ngoma  ...                 High               Medium
# 11481      O. Vargas      Obed Vargas  ...                 High               Medium
# 17591  A. Madaliński  Alan Madaliński  ...               Medium               Medium
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Value(in Euro)`    ``` inside .query()

# %%
# Write your own code

fifa23 = pd.read_csv("Data/fifa23_players_basic.csv")

mean_value = np.mean(fifa23["Value(in Euro)"])

players_above_mean = fifa23.query("`Value(in Euro)` > @mean_value")

display(players_above_mean)
# Out:
#             Known As  ... Defensive Work Rate
# 0           L. Messi  ...                 Low
# 1         K. Benzema  ...              Medium
# 2     R. Lewandowski  ...              Medium
# 3       K. De Bruyne  ...                High
# 4          K. Mbappé  ...                 Low
# ...              ...  ...                 ...
# 7066       F. Rieder  ...              Medium
# 7071     J. Bakayoko  ...              Medium
# 7090        M. Arezo  ...              Medium
# 7096       Y. Kallon  ...                 Low
# 7168        M. Soulé  ...              Medium
#
# [3216 rows x 32 columns]

# %% [markdown]
# <font size = "5">
